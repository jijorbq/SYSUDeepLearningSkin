# %%
import PIL,torch
import matplotlib.pyplot as plt
import torch.nn as nn
import numpy as np
import os
import time
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset,DataLoader
from torchvision.models import resnet50
from pytorchcv.model_provider import get_model as ptcv_get_model

# %%
class SkinDataset(Dataset):
    folds=5
    def __init__(self, root , num_classes,fold=0,training=False,n_augment=2):
        self.data_path = []
        self.sides =448
        self.n_augment = max(n_augment , 4)
        self.transform = transforms.Compose([
                transforms.RandomResizedCrop(size=(224, 224)),
                transforms.RandomRotation(5),
                transforms.ToTensor(),
                transforms.Normalize(mean= [0.6075306,0.49116918 ,0.46066117],std = [0.22603881, 0.21623525, 0.2191065 ])
            ]
            )
        self.training = training
        for label in range(num_classes):
            self.data_dir = os.path.join(root,os.listdir(root)[label])
            self.filename = os.listdir(self.data_dir)
            l = len(self.filename)
            inter = l//SkinDataset.folds
            picked = list(range(inter* fold,inter * (fold+1))) if not training else list(range(0,inter*fold))+list(range(inter*(fold+1),l))

            for i in picked:
                file_path = os.path.join(self.data_dir , self.filename[i])
#                 img = Image.open(fil)
                self.data_path.append((file_path, label))
    
    def __getitem__(self , index):
        index %= len(self.data_path)
        ddir , label = self.data_path[index]
        img = Image.open(ddir)
        imgmat = self.transform(img)
#         if self.training:
#             imgmat += torch.randn(3,self.sides,self.sides)/256
        result = (imgmat, label)
        del imgmat
        del img
        return result
    
    def __len__(self):
        return len(self.data_path)*self.n_augment

# %%
# del training_dataloader
batch_size = 128
lr = 0.1
suffix = '%f' % time.time()
log_dir = './log/%s'% suffix +'/'
EXPERIMENT = 'resnet50_%s'% str(lr)
os.mkdir(log_dir)
print(suffix)
print(log_dir)
print(EXPERIMENT)

training_dataset = SkinDataset(os.path.join(os.getcwd(),'./Skin40'), 40, training=True)
test_dataset = SkinDataset(os.path.join(os.getcwd(),'./Skin40'), 40)
training_dataloader = DataLoader(training_dataset , batch_size = batch_size , num_workers = 1, shuffle = True)
test_dataloader = DataLoader(test_dataset , batch_size = batch_size , num_workers = 1, shuffle = True)
# Out:
# 1592564017.628971
# ./log/1592564017.628971/
# resnet50_0.1

# %%
def train(model, train_loader, loss_func, optimizer, device):
    """
    train model using loss_fn and optimizer in an epoch.
    model: CNN networks
    train_loader: a Dataloader object with training data
    loss_func: loss function
    device: train on cpu or gpu device
    """
    total_loss = 0
    model.train()
    # train the model using minibatch
    for i, (images, targets) in enumerate(train_loader):
        images = images.to(device)
        targets = targets.to(device)
        
        # forward
        outputs = model(images)
        loss = loss_func(outputs, targets)

        # backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        # every  iterations, print loss
        if (i + 1) % (10) == 0:
            print ("Step [{}/{}] Train Loss: {:.4f}"
                   .format(i+1, len(train_loader), loss.item()))
    return total_loss / len(train_loader)

# %%
def evaluate(model, val_loader, device, nclasses):
    """
    model: CNN networks
    val_loader: a Dataloader object with validation data
    device: evaluate on cpu or gpu device
    return classification accuracy of the model on val dataset
    """
    # evaluate the model
    model.eval()
    # context-manager that disabled gradient computation
    with torch.no_grad():
        correct = 0
        total = 0
        cm = torch.zeros(nclasses, nclasses)
        for i, (images, targets) in enumerate(val_loader):
            # device: cpu or gpu
            images = images.to(device)
            targets = targets.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, dim=1)
            
            
            for t, p in zip(targets.view(-1), predicted.view(-1)):
                cm[t.long()][p.long()] +=1
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
        accuracy = correct / total
        print('Accuracy on Test Set: {:.4f} %'.format(100 * accuracy))
        show_heatmap(cm, nclasses)
        return accuracy,cm

# %%
import matplotlib.pyplot as plt
def show_curve(ys, title):
    """
    plot curlve for Loss and Accuacy
    Args:
        ys: loss or acc list
        title: loss or accuracy
    """
    x = np.array(range(len(ys)))
    y = np.array(ys)
    plt.plot(x, y, c='b')
    plt.axis()
    plt.title('{} curve'.format(title))
    plt.xlabel('epoch')
    plt.ylabel('{}'.format(title))
    plt.show()

def show_heatmap(cm, nclasses):
    labels = range(nclasses)
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    ax.set_yticks(labels)
    ax.set_yticklabels(labels)
    ax.set_xticks(labels)
    ax.set_xticklabels(labels)
    
    im = ax.imshow(cm, cmap=plt.cm.hot_r )
    plt.colorbar(im)
    plt.title("Confusioin Matrix")
    plt.show()
    print('Accuracy of each class:\n', cm.diag()/(cm.sum(1)+1e-6))
    print('Recall of each class:\n', cm.diag()/(cm.sum(0)+1e-6))

# %%
def fit(model, num_epochs, optimizer, schedulr, device,nclasses):
    """
     train and evaluate an classifier num_epochs times.
    n and evaluate an classifier num_epochs times.
    We use optimizer and cross entropy loss to train the model. 
    Args: 
        model: CNN network
        num_epochs: the number of training epochs
        optimizer: optimize the loss function    loss_func.to(device)
    loss_func.to(device)
        schedulr: scheduling learning rate

    """
    # loss and optimizer
    loss_func = nn.CrossEntropyLoss()
    
    model.to(device)
    loss_func.to(device)
    
    # log train loss and test accuracy
    losses = []
    accs = []
    cms = []
    for epoch in range(num_epochs):
        
        print('Epoch {}/{}: , lr = {}'.format(epoch + 1, num_epochs , optimizer.param_groups[0]['lr']))
        # train step
        loss = train(model, training_dataloader, loss_func, optimizer, device)
        losses.append(loss)
        schedulr.step()
        
        # evaluate step
        accuracy,cm = evaluate(model, test_dataloader, device,nclasses)
        accs.append(accuracy)
        cms.append(cm)
        torch.save(cm,log_dir+str(epoch)+'_cms.pth')   
        torch.save(loss,log_dir+str(epoch)+'_tls.pth')   
        torch.save(accuracy,log_dir+str(epoch)+'_tas.pth')   
    torch.save(cms,log_dir+EXPERIMENT+'_cms.pth')   
    torch.save(losses,log_dir+EXPERIMENT+'_tls.pth')   
    torch.save(accs,log_dir+EXPERIMENT+'_tas.pth')   
    # show curve
    show_curve(losses, "train loss")
    show_curve(accs, "test accuracy")

# %%
net = ptcv_get_model("resnet18", num_classes=40)

# %%
# Hyper-parameters
num_epochs = 40
nclasses = 40
feature_tune=False
# Device configuration
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# # optimizer
#optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, net.parameters()), lr=0.1)
optimizer = torch.optim.SGD(net.parameters(), lr=0.2)
schedulr = torch.optim.lr_scheduler.StepLR(optimizer , step_size = 4 , gamma = 0.5)
for name,param in net.named_parameters():
    print(param.requires_grad, name)
# Out:
# True features.init_block.conv.conv.weight
# True features.init_block.conv.bn.weight
# True features.init_block.conv.bn.bias
# True features.stage1.unit1.body.conv1.conv.weight
# True features.stage1.unit1.body.conv1.bn.weight
# True features.stage1.unit1.body.conv1.bn.bias
# True features.stage1.unit1.body.conv2.conv.weight
# True features.stage1.unit1.body.conv2.bn.weight
# True features.stage1.unit1.body.conv2.bn.bias
# True features.stage1.unit2.body.conv1.conv.weight
# True features.stage1.unit2.body.conv1.bn.weight
# True features.stage1.unit2.body.conv1.bn.bias
# True features.stage1.unit2.body.conv2.conv.weight
# True features.stage1.unit2.body.conv2.bn.weight
# True features.stage1.unit2.body.conv2.bn.bias
# True features.stage2.unit1.body.conv1.conv.weight
# True features.stage2.unit1.body.conv1.bn.weight
# True features.stage2.unit1.body.conv1.bn.bias
# True features.stage2.unit1.body.conv2.conv.weight
# True features.stage2.unit1.body.conv2.bn.weight
# True features.stage2.unit1.body.conv2.bn.bias
# True features.stage2.unit1.identity_conv.conv.weight
# True features.stage2.unit1.identity_conv.bn.weight
# True features.stage2.unit1.identity_conv.bn.bias
# True features.stage2.unit2.body.conv1.conv.weight
# True features.stage2.unit2.body.conv1.bn.weight
# True features.stage2.unit2.body.conv1.bn.bias
# True features.stage2.unit2.body.conv2.conv.weight
# True features.stage2.unit2.body.conv2.bn.weight
# True features.stage2.unit2.body.conv2.bn.bias
# True features.stage3.unit1.body.conv1.conv.weight
# True features.stage3.unit1.body.conv1.bn.weight
# True features.stage3.unit1.body.conv1.bn.bias
# True features.stage3.unit1.body.conv2.conv.weight
# True features.stage3.unit1.body.conv2.bn.weight
# True features.stage3.unit1.body.conv2.bn.bias
# True features.stage3.unit1.identity_conv.conv.weight
# True features.stage3.unit1.identity_conv.bn.weight
# True features.stage3.unit1.identity_conv.bn.bias
# True features.stage3.unit2.body.conv1.conv.weight
# True features.stage3.unit2.body.conv1.bn.weight
# True features.stage3.unit2.body.conv1.bn.bias
# True features.stage3.unit2.body.conv2.conv.weight
# True features.stage3.unit2.body.conv2.bn.weight
# True features.stage3.unit2.body.conv2.bn.bias
# True features.stage4.unit1.body.conv1.conv.weight
# True features.stage4.unit1.body.conv1.bn.weight
# True features.stage4.unit1.body.conv1.bn.bias
# True features.stage4.unit1.body.conv2.conv.weight
# True features.stage4.unit1.body.conv2.bn.weight
# True features.stage4.unit1.body.conv2.bn.bias
# True features.stage4.unit1.identity_conv.conv.weight
# True features.stage4.unit1.identity_conv.bn.weight
# True features.stage4.unit1.identity_conv.bn.bias
# True features.stage4.unit2.body.conv1.conv.weight
# True features.stage4.unit2.body.conv1.bn.weight
# True features.stage4.unit2.body.conv1.bn.bias
# True features.stage4.unit2.body.conv2.conv.weight
# True features.stage4.unit2.body.conv2.bn.weight
# True features.stage4.unit2.body.conv2.bn.bias
# True output.weight
# True output.bias

# %%
fit(net, num_epochs, optimizer, schedulr,device, nclasses)  #
# Out:
# Epoch 1/40: , lr = 0.1
# Step [10/60] Train Loss: 3.8227
# Step [20/60] Train Loss: 3.5100
# Step [30/60] Train Loss: 3.4226
# Step [40/60] Train Loss: 3.4215
# Step [50/60] Train Loss: 3.3635
# Step [60/60] Train Loss: 3.1720
# Accuracy on Test Set: 10.0000 %
# Accuracy of each class:
#  tensor([0.0208, 0.0000, 0.0000, 0.0833, 0.0000, 0.2917, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.4167, 0.1042, 0.0000, 0.0208, 0.0000, 0.0000,
#         0.0000, 0.8333, 0.1458, 0.0000, 0.2500, 0.0208, 0.0000, 0.0208, 0.0000,
#         0.1458, 0.1875, 0.0208, 0.2708, 0.0000, 0.1458, 0.1667, 0.0208, 0.0000,
#         0.0000, 0.2500, 0.1042, 0.4792])
# Recall of each class:
#  tensor([1.0000, 0.0000, 0.0000, 0.5000, 0.0000, 0.5000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0409, 0.1852, 0.0000, 0.2000, 0.0000, 0.0000,
#         0.0000, 0.1254, 0.3182, 0.0000, 0.1519, 1.0000, 0.0000, 0.3333, 0.0000,
#         0.1273, 0.1552, 0.0476, 0.1444, 0.0000, 0.1094, 0.1194, 0.0303, 0.0000,
#         0.0000, 0.0420, 0.0833, 0.1307])
# Epoch 2/40: , lr = 0.1
# Step [10/60] Train Loss: 3.0947
# Step [20/60] Train Loss: 2.9567
# Step [30/60] Train Loss: 3.1155
# Step [40/60] Train Loss: 2.8964
# Step [50/60] Train Loss: 2.9862
# Step [60/60] Train Loss: 2.8396
# Accuracy on Test Set: 12.3438 %
# Accuracy of each class:
#  tensor([0.0000, 0.0000, 0.1250, 0.6875, 0.1667, 0.5417, 0.0625, 0.1667, 0.0000,
#         0.0000, 0.1458, 0.0208, 0.0000, 0.3750, 0.0208, 0.0000, 0.2083, 0.0208,
#         0.0000, 0.0000, 0.5208, 0.0000, 0.0000, 0.7917, 0.0833, 0.0625, 0.0208,
#         0.1042, 0.0625, 0.0000, 0.1667, 0.0208, 0.0000, 0.0833, 0.4583, 0.0208,
#         0.0000, 0.0000, 0.0000, 0.0000])
# Recall of each class:
#  tensor([0.0000, 0.0000, 0.1818, 0.1480, 0.2000, 0.2016, 0.4286, 0.0930, 0.0000,
#         0.0000, 0.1077, 0.0156, 0.0000, 0.1192, 0.1429, 0.0000, 0.2273, 0.1250,
#         0.0000, 0.0000, 0.4386, 0.0000, 0.0000, 0.0955, 0.6667, 0.3000, 0.2000,
#         0.0667, 0.0441, 0.0000, 0.1739, 0.0417, 0.0000, 0.0870, 0.0759, 0.0435,
#         0.0000, 0.0000, 0.0000, 0.0000])
# Epoch 3/40: , lr = 0.05
# Step [10/60] Train Loss: 2.4572
# Step [20/60] Train Loss: 2.7893
# Step [30/60] Train Loss: 2.6851
# Step [40/60] Train Loss: 2.4318
# Step [50/60] Train Loss: 2.7353
# Step [60/60] Train Loss: 2.5683
# Accuracy on Test Set: 21.3542 %
# Accuracy of each class:
#  tensor([0.1875, 0.1667, 0.2292, 0.3958, 0.2708, 0.0625, 0.2083, 0.3333, 0.0625,
#         0.1667, 0.1250, 0.1042, 0.1250, 0.4375, 0.1458, 0.4375, 0.4167, 0.1042,
#         0.4583, 0.3958, 0.3542, 0.0625, 0.1667, 0.2500, 0.0625, 0.5833, 0.1875,
#         0.2083, 0.0208, 0.3750, 0.1042, 0.0000, 0.2292, 0.1458, 0.1042, 0.1667,
#         0.0625, 0.0833, 0.4583, 0.0833])
# Recall of each class:
#  tensor([0.1098, 0.1194, 0.2821, 0.6552, 0.1912, 0.1500, 0.6667, 0.2162, 0.1875,
#         0.0816, 0.1935, 0.1562, 0.4000, 0.1875, 0.1111, 0.2121, 0.1681, 0.1389,
#         0.2157, 0.3654, 0.7727, 0.0857, 0.1667, 0.8000, 0.3000, 0.6222, 0.3000,
#         0.0862, 0.2500, 0.1224, 0.2500, 0.0000, 0.2500, 0.1522, 0.1852, 0.1951,
#         0.7500, 0.1818, 0.3492, 0.4000])
# Epoch 4/40: , lr = 0.05
# Step [10/60] Train Loss: 2.7501
# Step [20/60] Train Loss: 2.4652
# Step [30/60] Train Loss: 2.5327
# Step [40/60] Train Loss: 2.4142
# Step [50/60] Train Loss: 2.2361
# Step [60/60] Train Loss: 2.3062
# Accuracy on Test Set: 21.3542 %
# Accuracy of each class:
#  tensor([0.0208, 0.2708, 0.4167, 0.6042, 0.0625, 0.1667, 0.3750, 0.2292, 0.0208,
#         0.0208, 0.2708, 0.2292, 0.0000, 0.0208, 0.1250, 0.2708, 0.1042, 0.2292,
#         0.2500, 0.0000, 0.7708, 0.0833, 0.1042, 0.7708, 0.1667, 0.5417, 0.0833,
#         0.0625, 0.0000, 0.4167, 0.1042, 0.0625, 0.2083, 0.1875, 0.0417, 0.1667,
#         0.7917, 0.0417, 0.0833, 0.1667])
# Recall of each class:
#  tensor([0.0625, 0.2766, 0.2020, 0.4143, 0.0484, 0.3200, 0.1324, 0.2821, 0.1111,
#         0.0714, 0.2321, 0.1134, 0.0000, 1.0000, 0.3529, 0.3611, 0.2778, 0.1774,
#         0.3636, 0.0000, 0.2139, 0.2500, 0.0510, 0.2434, 0.1633, 0.3824, 0.1176,
#         0.2727, 0.0000, 0.2778, 0.2000, 0.3750, 0.1639, 0.1286, 0.1176, 0.1509,
#         0.3800, 0.1667, 0.6667, 0.2424])
# Epoch 5/40: , lr = 0.025
# Step [10/60] Train Loss: 2.3599
# Step [20/60] Train Loss: 2.3026
# Step [30/60] Train Loss: 2.2424
# Step [40/60] Train Loss: 2.2578
# Step [50/60] Train Loss: 2.1994
# Step [60/60] Train Loss: 2.1586
# Accuracy on Test Set: 23.8542 %
# Accuracy of each class:
#  tensor([0.1875, 0.2708, 0.2500, 0.6250, 0.1667, 0.1875, 0.2083, 0.1667, 0.0625,
#         0.1042, 0.1667, 0.1250, 0.1042, 0.3750, 0.1250, 0.3333, 0.0208, 0.2708,
#         0.1042, 0.6250, 0.7500, 0.0833, 0.1667, 0.4375, 0.1250, 0.5417, 0.2292,
#         0.0417, 0.0625, 0.4375, 0.1875, 0.2083, 0.0417, 0.2500, 0.1667, 0.5625,
#         0.5625, 0.0000, 0.0833, 0.1250])
# Recall of each class:
#  tensor([0.1667, 0.2889, 0.4000, 0.3409, 0.1356, 0.2250, 0.1449, 0.1818, 0.1154,
#         0.0617, 0.2667, 0.0952, 0.1724, 0.2169, 0.1364, 0.4706, 0.0714, 0.2889,
#         0.2381, 0.3226, 0.4737, 0.5000, 0.1404, 0.5250, 0.1538, 0.6047, 0.1897,
#         0.5000, 0.2000, 0.2019, 0.2143, 0.1695, 0.0690, 0.2400, 0.3333, 0.1324,
#         0.6429, 0.0000, 0.4000, 0.3333])
# Epoch 6/40: , lr = 0.025
# Step [10/60] Train Loss: 2.0109
# Step [20/60] Train Loss: 2.0141
# Step [30/60] Train Loss: 2.1838
# Step [40/60] Train Loss: 2.2731
# Step [50/60] Train Loss: 2.1588
# Step [60/60] Train Loss: 1.9731
# Accuracy on Test Set: 28.9583 %
# Accuracy of each class:
#  tensor([0.2708, 0.2292, 0.4167, 0.4375, 0.1042, 0.4583, 0.0625, 0.2917, 0.0625,
#         0.0833, 0.3542, 0.1667, 0.0833, 0.2500, 0.1458, 0.4583, 0.3750, 0.5417,
#         0.3125, 0.6042, 0.7917, 0.0625, 0.1250, 0.5208, 0.0625, 0.6875, 0.3750,
#         0.1458, 0.1875, 0.4375, 0.2500, 0.2292, 0.2292, 0.1667, 0.1042, 0.2083,
#         0.6458, 0.0000, 0.4167, 0.2292])
# Recall of each class:
#  tensor([0.2826, 0.2750, 0.3030, 0.6774, 0.1042, 0.3548, 0.1667, 0.1609, 0.2308,
#         0.0800, 0.3864, 0.1600, 0.3333, 0.1538, 0.2333, 0.2136, 0.2609, 0.3768,
#         0.2308, 0.4754, 0.5067, 0.2500, 0.2308, 0.6944, 0.0857, 0.3000, 0.1636,
#         0.4375, 0.2045, 0.3684, 0.2609, 0.3667, 0.2619, 0.2051, 0.3571, 0.2500,
#         0.4306, 0.0000, 0.5405, 0.3056])
# Epoch 7/40: , lr = 0.0125
# Step [10/60] Train Loss: 1.9111
# Step [20/60] Train Loss: 1.9206
# Step [30/60] Train Loss: 2.0745
# Step [40/60] Train Loss: 1.8619
# Step [50/60] Train Loss: 1.9451
# Step [60/60] Train Loss: 1.8945
# Accuracy on Test Set: 30.1562 %
# Accuracy of each class:
#  tensor([0.2708, 0.2292, 0.5625, 0.6667, 0.2500, 0.2708, 0.2083, 0.3125, 0.0417,
#         0.0625, 0.3958, 0.2917, 0.1042, 0.1250, 0.1042, 0.4167, 0.1667, 0.4583,
#         0.3750, 0.4583, 0.7917, 0.1042, 0.1458, 0.5625, 0.1875, 0.7083, 0.3542,
#         0.1667, 0.3125, 0.5208, 0.1458, 0.1667, 0.2083, 0.1250, 0.3125, 0.3958,
#         0.4167, 0.1458, 0.3542, 0.1667])
# Recall of each class:
#  tensor([0.2549, 0.3793, 0.3699, 0.7273, 0.1558, 0.3421, 0.2273, 0.2727, 0.1818,
#         0.1500, 0.3115, 0.1386, 0.2000, 0.2609, 0.1613, 0.2857, 0.1667, 0.2366,
#         0.3600, 0.5000, 0.4935, 0.2381, 0.1750, 0.4355, 0.2195, 0.6296, 0.3208,
#         0.2857, 0.2027, 0.5000, 0.1944, 0.2759, 0.1923, 0.1091, 0.2239, 0.3519,
#         0.4651, 0.2258, 0.4146, 0.3333])
# Epoch 8/40: , lr = 0.0125
# Step [10/60] Train Loss: 2.0364
# Step [20/60] Train Loss: 1.9358
# Step [30/60] Train Loss: 1.9800
# Step [40/60] Train Loss: 2.0242
# Step [50/60] Train Loss: 2.2088
# Step [60/60] Train Loss: 2.0115
# Accuracy on Test Set: 30.1562 %
# Accuracy of each class:
#  tensor([0.2500, 0.2708, 0.3750, 0.5833, 0.1875, 0.2083, 0.2708, 0.3542, 0.1667,
#         0.0833, 0.2292, 0.2083, 0.1667, 0.2917, 0.1042, 0.3542, 0.2500, 0.3750,
#         0.2708, 0.5000, 0.7292, 0.0625, 0.1042, 0.6042, 0.1875, 0.8125, 0.2917,
#         0.2083, 0.1458, 0.3958, 0.2292, 0.0833, 0.3333, 0.2500, 0.2292, 0.3958,
#         0.6875, 0.1458, 0.3542, 0.3125])
# Recall of each class:
#  tensor([0.3243, 0.3095, 0.2951, 0.4746, 0.1800, 0.2778, 0.2241, 0.3400, 0.2857,
#         0.1333, 0.4074, 0.1408, 0.2500, 0.2258, 0.0962, 0.1977, 0.2182, 0.3103,
#         0.2766, 0.6667, 0.4795, 0.1304, 0.2381, 0.5370, 0.2045, 0.4643, 0.3043,
#         0.2381, 0.1667, 0.4222, 0.2292, 0.2222, 0.2909, 0.1538, 0.2391, 0.3455,
#         0.6000, 0.1667, 0.5862, 0.3488])
# Epoch 9/40: , lr = 0.00625
# Step [10/60] Train Loss: 1.7555
# Step [20/60] Train Loss: 1.9690
# Step [30/60] Train Loss: 1.9075
# Step [40/60] Train Loss: 1.8151
# Step [50/60] Train Loss: 1.9560
# Step [60/60] Train Loss: 1.9000
# Accuracy on Test Set: 32.4479 %
# Accuracy of each class:
#  tensor([0.2708, 0.4167, 0.5833, 0.5833, 0.1667, 0.2708, 0.1875, 0.3958, 0.0833,
#         0.0625, 0.3958, 0.2083, 0.1875, 0.2292, 0.1250, 0.4375, 0.3958, 0.4167,
#         0.4167, 0.6875, 0.6667, 0.0417, 0.1042, 0.7083, 0.1667, 0.8333, 0.2500,
#         0.1875, 0.2083, 0.4583, 0.0833, 0.1667, 0.2708, 0.2708, 0.1667, 0.4583,
#         0.5625, 0.1042, 0.4167, 0.3333])
# Recall of each class:
#  tensor([0.2549, 0.3704, 0.3077, 0.5000, 0.1739, 0.2549, 0.2308, 0.3725, 0.0976,
#         0.1429, 0.3725, 0.2083, 0.2432, 0.3143, 0.1364, 0.4038, 0.2346, 0.2857,
#         0.3922, 0.5789, 0.5000, 0.0833, 0.1429, 0.4416, 0.2857, 0.5128, 0.3429,
#         0.2500, 0.3333, 0.4783, 0.2105, 0.1739, 0.3023, 0.2167, 0.2353, 0.3793,
#         0.5192, 0.1389, 0.5714, 0.2807])
# Epoch 10/40: , lr = 0.00625
# Step [10/60] Train Loss: 1.8971
# Step [20/60] Train Loss: 1.7858
# Step [30/60] Train Loss: 1.7227
# Step [40/60] Train Loss: 1.9816
# Step [50/60] Train Loss: 1.8812
# Step [60/60] Train Loss: 1.9214
# Accuracy on Test Set: 31.2500 %
# Accuracy of each class:
#  tensor([0.2083, 0.3542, 0.5833, 0.6042, 0.1458, 0.3333, 0.2917, 0.3750, 0.0833,
#         0.1458, 0.3750, 0.2292, 0.1250, 0.2708, 0.1667, 0.3750, 0.1250, 0.3958,
#         0.3958, 0.6875, 0.6875, 0.1042, 0.1458, 0.6250, 0.2708, 0.7917, 0.2500,
#         0.2083, 0.1042, 0.4583, 0.0833, 0.1250, 0.2083, 0.2292, 0.1667, 0.5000,
#         0.6042, 0.0833, 0.3333, 0.2500])
# Recall of each class:
#  tensor([0.3704, 0.3036, 0.3544, 0.6042, 0.1296, 0.3137, 0.2642, 0.2769, 0.2353,
#         0.3500, 0.2903, 0.1719, 0.2609, 0.3095, 0.1860, 0.2432, 0.1818, 0.2676,
#         0.3333, 0.4521, 0.5690, 0.1923, 0.1373, 0.5769, 0.2131, 0.6441, 0.3243,
#         0.2128, 0.1613, 0.3793, 0.1667, 0.1538, 0.2273, 0.1429, 0.2162, 0.4364,
#         0.5370, 0.2000, 0.3721, 0.3429])
# Epoch 11/40: , lr = 0.003125
# Step [10/60] Train Loss: 1.9102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f33bc8219cb5> in <module>
# ----> 1 fit(net, num_epochs, optimizer, schedulr,device, nclasses)  #
#
# <ipython-input-7-c21a77f44d08> in fit(model, num_epochs, optimizer, schedulr, device, nclasses)
#      26         print('Epoch {}/{}: , lr = {}'.format(epoch + 1, num_epochs , optimizer.param_groups[0]['lr']))
#      27         # train step
# ---> 28         loss = train(model, training_dataloader, loss_func, optimizer, device)
#      29         losses.append(loss)
#      30         schedulr.step()
#
# <ipython-input-4-0ebe9d12665c> in train(model, train_loader, loss_func, optimizer, device)
#      23         optimizer.step()
#      24
# ---> 25         total_loss += loss.item()
#      26
#      27         # every  iterations, print loss
#
# KeyboardInterrupt:
